# %%
import base64

# Open the image file
with open("SampleImages/plant6.jpeg", "rb") as image_file:  # Replace "image.jpg" with your image file path
    # Read the image file content
    image_data = image_file.read()
    # Encode the image data to base64
    base64_encoded_image = base64.b64encode(image_data).decode()

# %%
base64_encoded_image
# Out:
# '...'

# %%
import requests
import json

# Define the ngrok URL
ngrok_url = "https://plant-doctor-cmikj7tppa-uc.a.run.app"  # Replace with your ngrok URL

# Define the endpoint URL
endpoint_url = ngrok_url + "/process_image/"

# Define the JSON payload
payload = {
    "image": base64_encoded_image,
    "latitude": '20',  # Replace with your latitude
    "longitude": '74',  # Replace with your longitude
    "lang": 'Hindi'
}

# Convert payload to JSON string
payload_json = json.dumps(payload)

# Send POST request
response = requests.post(endpoint_url, data=payload_json)

# Check the response
if response.status_code == 200:
    print("Request successful!")
    print("Response:", response.json())
else:
    print("Request failed with status code:", response.status_code)
    print("Response:", response.text)
# Out:
# Request successful!
# Response: {'report': 'चित्र में दिख रहा पौधा एक हरा प्याज़ है। हरा प्याज़ एक प्रकार का प्याज़ है, जिसे प्याज के गोले के पूरी तरह विकसित होने से पहले ही काट लिया जाता है। इसे स्प्रिंग प्याज़ या स्कैलियन के नाम से भी जाना जाता है। हरा प्याज़ एक ठंडे मौसम वाला फसल है, जो आम तौर पर वसंत और पतझड़ में उगाया जाता है। इसे विभिन्न प्रकार की मिट्टी में उगाया जा सकता है, लेकिन यह कार्बनिक पदार्थों से भरपूर अच्छी जल निकासी वाली मिट्टी को तरजीह देता है। हरे प्याज को ठीक ढंग से बढ़ने के लिए अच्छी धूप की आवश्यकता होती है।\n\nचित्र में दिख रहा हरा प्याज स्वस्थ प्रतीत हो रहा है। इसकी पत्तियां हरी और रसीली हैं और उसमें कीटों या बीमारियों के कोई संकेत दिखाई नहीं दे रहे हैं। पौधा कार्बनिक पदार्थों से भरपूर अच्छी जल निकासी वाली मिट्टी में उग रहा है। हरे प्याज के विकास के लिए मौसम की स्थिति भी आदर्श है। मौसम ठंडा है और तेज धूप खिली हुई है।\n\nकुल मिलाकर, चित्र में दिख रहा हरा प्याज स्वस्थ प्रतीत हो रहा है और उसे किसी विशेष देखभाल की आवश्यकता नहीं है। हालांकि, कीटों या बीमारियों के संकेतों को लेकर पौधे पर नजर रखना महत्वपूर्ण है। अगर कोई भी समस्या दिखाई देती है, तो उसका तुरंत इलाज किया जाना चाहिए।\n\nवर्तमान मौसम की स्थिति हरे प्याज की ग्रोथ के लिए आदर्श है। मौसम ठंडा है और तेज धूप खिली हुई है। भविष्य के लिए मौसम का पूर्वानुमान भी हरे प्याज की ग्रोथ के लिए अनुकूल है। मौसम ठंडा रहेगा और तेज धूप खिली रहेगी। हालांकि, निकट भविष्य में बारिश का मौसम है। इससे पौधों को पानी मिल सकेगा, लेकिन इससे फंगल बीमारियों की भी समस्या हो सकती है। पौधों पर नजर रखना और यह सुनिश्चित करना महत्वपूर्ण है कि उन्हें बहुत अधिक पानी न मिल जाए।'}

# %%
import json
resp = json.loads(response.text)
print(resp['report'])
# Out:
# चित्र में दिख रहा पौधा एक हरा प्याज़ है। हरा प्याज़ एक प्रकार का प्याज़ है, जिसे प्याज के गोले के पूरी तरह विकसित होने से पहले ही काट लिया जाता है। इसे स्प्रिंग प्याज़ या स्कैलियन के नाम से भी जाना जाता है। हरा प्याज़ एक ठंडे मौसम वाला फसल है, जो आम तौर पर वसंत और पतझड़ में उगाया जाता है। इसे विभिन्न प्रकार की मिट्टी में उगाया जा सकता है, लेकिन यह कार्बनिक पदार्थों से भरपूर अच्छी जल निकासी वाली मिट्टी को तरजीह देता है। हरे प्याज को ठीक ढंग से बढ़ने के लिए अच्छी धूप की आवश्यकता होती है।
#
# चित्र में दिख रहा हरा प्याज स्वस्थ प्रतीत हो रहा है। इसकी पत्तियां हरी और रसीली हैं और उसमें कीटों या बीमारियों के कोई संकेत दिखाई नहीं दे रहे हैं। पौधा कार्बनिक पदार्थों से भरपूर अच्छी जल निकासी वाली मिट्टी में उग रहा है। हरे प्याज के विकास के लिए मौसम की स्थिति भी आदर्श है। मौसम ठंडा है और तेज धूप खिली हुई है।
#
# कुल मिलाकर, चित्र में दिख रहा हरा प्याज स्वस्थ प्रतीत हो रहा है और उसे किसी विशेष देखभाल की आवश्यकता नहीं है। हालांकि, कीटों या बीमारियों के संकेतों को लेकर पौधे पर नजर रखना महत्वपूर्ण है। अगर कोई भी समस्या दिखाई देती है, तो उसका तुरंत इलाज किया जाना चाहिए।
#
# वर्तमान मौसम की स्थिति हरे प्याज की ग्रोथ के लिए आदर्श है। मौसम ठंडा है और तेज धूप खिली हुई है। भविष्य के लिए मौसम का पूर्वानुमान भी हरे प्याज की ग्रोथ के लिए अनुकूल है। मौसम ठंडा रहेगा और तेज धूप खिली रहेगी। हालांकि, निकट भविष्य में बारिश का मौसम है। इससे पौधों को पानी मिल सकेगा, लेकिन इससे फंगल बीमारियों की भी समस्या हो सकती है। पौधों पर नजर रखना और यह सुनिश्चित करना महत्वपूर्ण है कि उन्हें बहुत अधिक पानी न मिल जाए।

# %%
endpoint_url
# Out:
# 'https://plant-doctor-cmikj7tppa-uc.a.run.app/process_image/'

# %%
# from PIL import Image
# from io import BytesIO

# image = "YmxvYjpodHRwczovL3gudGh1bmthYmxlLmNvbS8xZjFjN2JjMS01ZjFhLTQxZTYtYmU5ZC01ZGU5M2VjNDA2MzE="
# image_data = base64.b64decode(image)
# image = Image.open(BytesIO(image_data))
# image.show()

# %%
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from geopy) (2.0)
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
from geopy.geocoders import Nominatim

geocoder = Nominatim(user_agent = 'plant_doctor')
lat,long = 12.9715987,77.5945667
location = geocoder.reverse((lat, long))
print(location.address)
# Out:
# St. Joseph's Indian High School, 1st Cross Road, D'Souza Layout, Shantala Nagar, East Zone, Bengaluru, Bangalore North, Bengaluru Urban District, Karnataka, 560001, India

# %%
location.altitude
# Out:
# 0.0

# %%
location.address
# Out:
# "St. Joseph's Indian High School, Vittal Mallya Road, D'Souza Layout, Shantala Nagar, East Zone, Bengaluru, Bangalore North, Bengaluru Urban District, Karnataka, 560001, India"

# %%
WEATHER_API_KEY = 'b47ace35de354224a94185025242402'
import requests

url = "https://api.worldweatheronline.com/premium/v1/weather.ashx"
api_key = WEATHER_API_KEY
latitude = "19"  # Latitude
longitude = "72"  # Longitude
num_of_days = 7  # Number of days of forecast
format_type = "json"  # Output format (json, xml, csv, tab, etc.)

params = {
    "q": f"{latitude},{longitude}",
    "num_of_days": num_of_days,
    "format": format_type,
    "key": api_key,
    "mca": "yes",
    "fx24": "yes",
    "aqi": "yes",
    "alerts": "yes",
}

response = requests.get(url, params=params)

if response.status_code == 200:
    data = response.json()
    # Process the data here as needed
    print(data)
else:
    print("Error:", response.status_code)
# Out:
# {'data': {'request': [{'type': 'LatLon', 'query': 'Lat 19.00 and Lon 72.00'}], 'current_condition': [{'observation_time': '11:15 PM', 'temp_C': '23', 'temp_F': '74', 'weatherCode': '113', 'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}], 'weatherDesc': [{'value': 'Clear '}], 'windspeedMiles': '11', 'windspeedKmph': '18', 'winddirDegree': '22', 'winddir16Point': 'NNE', 'precipMM': '0.0', 'precipInches': '0.0', 'humidity': '34', 'visibility': '10', 'visibilityMiles': '6', 'pressure': '1010', 'pressureInches': '30', 'cloudcover': '0', 'FeelsLikeC': '24', 'FeelsLikeF': '76', 'uvIndex': '1', 'air_quality': {'co': '627.5', 'no2': '22.3', 'o3': '77.3', 'so2': '39.6', 'pm2_5': '34.5', 'pm10': '49.2', 'us-epa-index': '2', 'gb-defra-index': '2'}}], 'weather': [{'date': '2024-02-25', 'astronomy': [{'sunrise': '07:01 AM', 'sunset': '06:43 PM', 'moonrise': '07:30 PM', 'moonset': '07:32 AM', 'moon_phase': 'Waning Gibbous', 'moon_illumination': '100'}], 'maxtempC': '28', 'maxtempF': '83', 'mintempC': '23', 'mintempF': '73', 'avgtempC': '26', 'avgtempF': '78', 'totalSnow_cm': '0.0', 'sunHour': '11.4', 'uvIndex': '10', 'air_quality': {'co': '1811.0583333333332', 'no2': '61.0625', 'o3': '86.15833333333335', 'so2': '62.65', 'pm2_5': '131.3625', 'pm10': '168.8416666666667', 'us-epa-index': '4', 'gb-defra-index': '4'}, 'hourly': [{'time': '24', 'tempC': '28', 'tempF': '83', 'windspeedMiles': '19', 'windspeedKmph': '30', 'winddirDegree': '152', 'winddir16Point': 'SSE', 'weatherCode': '113', 'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}], 'weatherDesc': [{'value': 'Sunny'}], 'precipMM': '0.0', 'precipInches': '0.0', 'humidity': '41', 'visibility': '10', 'visibilityMiles': '6', 'pressure': '1010', 'pressureInches': '30', 'cloudcover': '1', 'HeatIndexC': '26', 'HeatIndexF': '79', 'DewPointC': '11', 'DewPointF': '52', 'WindChillC': '26', 'WindChillF': '78', 'WindGustMiles': '19', 'WindGustKmph': '31', 'FeelsLikeC': '26', 'FeelsLikeF': '79', 'chanceofrain': '0', 'chanceofremdry': '83', 'chanceofwindy': '0', 'chanceofovercast': '0', 'chanceofsunshine': '85', 'chanceoffrost': '0', 'chanceofhightemp': '57', 'chanceoffog': '0', 'chanceofsnow': '0', 'chanceofthunder': '0', 'uvIndex': '10', 'shortRad': '0.0', 'diffRad': '0.0', 'air_quality': {'co': '1811.0583333333332', 'no2': '61.0625', 'o3': '86.15833333333335', 'so2': '62.65', 'pm2_5': '131.3625', 'pm10': '168.8416666666667', 'us-epa-index': '4', 'gb-defra-index': '4'}}, {'time': '0', 'tempC': '25', 'tempF': '76', 'windspeedMiles': '9', 'windspeedKmph': '14', 'winddirDegree': '15', 'winddir16Point': 'NNE', 'weatherCode': '113', 'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}], 'weatherDesc': [{'value': 'Clear '}], 'precipMM': '0.0', 'precipInches': '0.0', 'humidity': '42', 'visibility': '10', 'visibilityMiles': '6', 'pressure': '1012', 'pressureInches': '30', 'cloudcover': '0', 'HeatIndexC': '25', 'HeatIndexF': '78', 'DewPointC': '11', 'DewPointF': '52', 'WindChillC': '25', 'WindChillF': '76', 'WindGustMiles': '15', 'WindGustKmph': '24', 'FeelsLikeC': '25', 'FeelsLikeF': '78', 'chanceofrain': '0', 'chanceofremdry': '82', 'chanceofwindy': '0', 'chanceofovercast': '0', 'chanceofsunshine': '94', 'chanceoffrost': '0', 'chanceofhightemp': '15', 'chanceoffog': '0', 'chanceofsnow': '0', 'chanceofthunder': '0', 'uvIndex': '1', 'shortRad': '0.0', 'diffRad': '0.0', 'air_quality': {'co': '867.8', 'no2': '35', 'o3': '95.8', 'so2': '60.6', 'pm2_5': '60.2', 'pm10': '85', 'us-epa-index': '3', 'gb-defra-index': '3'}}, {'time': '300', 'tempC': '24', 'tempF': '75', 'windspeedMiles': '11', 'windspeedKmph': '18', 'winddirDegree': '27', 'winddir16Point': 'NNE', 'weatherCode': '113', 'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],  ...

# %%
data
# Out:
# {'data': {'request': [{'type': 'LatLon', 'query': 'Lat 19.00 and Lon 72.00'}],
#   'current_condition': [{'observation_time': '07:17 PM',
#     'temp_C': '25',
#     'temp_F': '77',
#     'weatherCode': '122',
#     'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#     'weatherDesc': [{'value': 'Smoke'}],
#     'windspeedMiles': '6',
#     'windspeedKmph': '9',
#     'winddirDegree': '360',
#     'winddir16Point': 'N',
#     'precipMM': '0.0',
#     'precipInches': '0.0',
#     'humidity': '28',
#     'visibility': '3',
#     'visibilityMiles': '1',
#     'pressure': '1012',
#     'pressureInches': '30',
#     'cloudcover': '0',
#     'FeelsLikeC': '25',
#     'FeelsLikeF': '78',
#     'uvIndex': '1',
#     'air_quality': {'co': '734.3',
#      'no2': '29.8',
#      'o3': '85.1',
#      'so2': '53.4',
#      'pm2_5': '48.5',
#      'pm10': '68',
#      'us-epa-index': '3',
#      'gb-defra-index': '3'}}],
#   'weather': [{'date': '2024-02-25',
#     'astronomy': [{'sunrise': '07:01 AM',
#       'sunset': '06:43 PM',
#       'moonrise': '07:30 PM',
#       'moonset': '07:32 AM',
#       'moon_phase': 'Waning Gibbous',
#       'moon_illumination': '100'}],
#     'maxtempC': '28',
#     'maxtempF': '83',
#     'mintempC': '23',
#     'mintempF': '73',
#     'avgtempC': '26',
#     'avgtempF': '78',
#     'totalSnow_cm': '0.0',
#     'sunHour': '11.4',
#     'uvIndex': '10',
#     'air_quality': {'co': '1811.0583333333332',
#      'no2': '61.0625',
#      'o3': '86.15833333333335',
#      'so2': '62.65',
#      'pm2_5': '131.3625',
#      'pm10': '168.8416666666667',
#      'us-epa-index': '4',
#      'gb-defra-index': '4'},
#     'hourly': [{'time': '24',
#       'tempC': '28',
#       'tempF': '83',
#       'windspeedMiles': '19',
#       'windspeedKmph': '30',
#       'winddirDegree': '152',
#       'winddir16Point': 'SSE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '41',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1010',
#       'pressureInches': '30',
#       'cloudcover': '1',
#       'HeatIndexC': '26',
#       'HeatIndexF': '79',
#       'DewPointC': '11',
#       'DewPointF': '52',
#       'WindChillC': '26',
#       'WindChillF': '78',
#       'WindGustMiles': '19',
#       'WindGustKmph': '31',
#       'FeelsLikeC': '26',
#       'FeelsLikeF': '79',
#       'chanceofrain': '0',
#       'chanceofremdry': '83',
#       'chanceofwindy': '0',
#       'chanceofovercast': '0',
#       'chanceofsunshine': '85',
#       'chanceoffrost': '0',
#       'chanceofhightemp': '57',
#       'chanceoffog': '0',
#       'chanceofsnow': '0',
#       'chanceofthunder': '0',
#       'uvIndex': '10',
#       'shortRad': '0.0',
#       'diffRad': '0.0',
#       'air_quality': {'co': '1811.0583333333332',
#        'no2': '61.0625',
#        'o3': '86.15833333333335',
#        'so2': '62.65',
#        'pm2_5': '131.3625',
#        'pm10': '168.8416666666667',
#        'us-epa-index': '4',
#        'gb-defra-index': '4'}},
#      {'time': '0',
#       'tempC': '25',
#       'tempF': '76',
#       'windspeedMiles': '9',
#       'windspeedKmph': '14',
#       'winddirDegree': '15',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear '}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '42',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1012',
#       'pressureInches': '30',
#       'cloudcover': '0',
#       'HeatIndexC': '25',
#       'HeatIndexF': '78',
#       'DewPointC': '11',
#       'DewPointF': '52',
#       'WindChillC': '25',
#       'WindChillF': '76',
#       'WindGustMiles': '15',
#       'WindGustKmph': '24',
#       'FeelsLikeC': '25',
#       'FeelsLikeF': '78',
#       'chanceofrain': '0',
#       'chanceofremdry': '82',
#       'chanceofwindy': '0',
#       'chanceofovercast': '0',
#       'chanceofsunshine': '94',
#       'chanceoffrost': '0',
#       'chanceofhightemp': '15',
#       'chanceoffog': '0',
#       'chanceofsnow': '0',
#       'chanceofthunder': '0',
#       'uvIndex': '1',
#       'shortRad': '0.0',
#       'diffRad': '0.0',
#       'air_quality': {'co': '867.8',
#        'no2': '35',
#        'o3': '95.8',
#        'so2': '60.6',
#        'pm2_5': '60.2',
#        'pm10': '85',
#        'us-epa-index': '3',
#        'gb-defra-index': '3'}},
#      {'time': '300',
#       'tempC': '24',
#       'tempF': '75',
#       'windspeedMiles': '11',
#       'windspeedKmph': '18',
#       'winddirDegree': '27',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear '}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '35',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1010',
#       'pressureInches': '30',
#       'cloudcover': '0',
#       'HeatIndexC': '24',
#       'HeatIndexF': '76',
#       'DewPointC': '8',
#       'DewPointF': '46',
#       'WindChillC': '24',
#       'WindChillF': '75',
#       'WindGustMiles': '18',
#       'WindGustKmph': '29',
#       'FeelsLikeC': '24',
#       'FeelsLikeF': '76',
#       'chanceofrain': '0',
#       'chanceofremdry': '94',
#       'chanceofwindy': '0',
#       'chanceofovercast': '0',
#       'chanceofsunshine': '93',
#       'chanceoffrost': '0',
#       'chanceofhightemp': '10',
#       'chanceoffog': '0',
#       'chanceofsnow': '0',
#       'chanceofthunder': '0',
#       'uvIndex': '1',
#       'shortRad': '0.0',
#       'diffRad': '0.0',
#       'air_quality': {'co': '607.5',
#        'no2': '22.6',
#        'o3': '79.4',
#        'so2': '41.5',
#        'pm2_5': '34.4',
#        'pm10': '48.8',
#        'us-epa-index': '2',
#        'gb-defra-index': '2'}},
#      {'time': '600',
#       'tempC': '23',
#       'tempF': '74',
#       'windspeedMiles': '12',
#       'windspeedKmph': '19',
#       'winddirDegree': '26',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear '}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '31',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1011',
#       'pressureInches': '30',
#       'cloudcover': '0',
#       'HeatIndexC': '24',
#       'HeatIndexF': '75',
#       'DewPointC': '5',
#       'DewPointF': '41',
#       'WindChillC': '23',
#       'WindChillF': '74',
#       'WindGustMiles': '19',
#       'WindGustKmph': '30',
#       'FeelsLikeC': '24',
#       'FeelsLikeF': '75',
#       'chanceofrain': '0',
#       'chanceofremdry': '83',
#       'chanceofwindy': '0',
#       'chanceofovercast': '0',
#       'chanceofsunshine': '87',
#       'chanceoffrost': '0',
#       'chanceofhightemp': '10',
#       'chanceoffog': '0',
#       'chanceofsnow': '0',
#       'chanceofthunder': '0',
#       'uvIndex': '1',
#       'shortRad': '0.0',
#       'diffRad': '0.0',
#       'air_quality': {'co': '747.7',
#        'no2': '27.4',
#        'o3': '69.4',
#        'so2': '42.4',
#        'pm2_5': '40.1',
#        'pm10': '56.8',
#        'us-epa-index': '2',
#        'gb-defra-index': '2'}},
#      {'time': '900',
#       'tempC': '24',
#       'tempF': '76',
#       'windspeedMiles': '9',
#       'windspeedKmph': '15',
#       'winddirDegree': '45',
#       'winddir16Point': 'NE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '26',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1013',
#       'pressureInches': '30',
#       'cloudcover': '0',
#       'HeatIndexC': '24',
#       'HeatIndexF': '75',
#       'DewPointC': '4',
#       'DewPointF': '38',
#       'WindChillC': '24',
#       'WindChillF': '76',
#       'WindGustMiles': '13',
#       'WindGustKmph': '21',
#       'FeelsLikeC': '24',
#       'FeelsLikeF': '75',
#       'chanceofrain': '0',
#       'chanceofremdry': '84',
#       'chanceofwindy': '0',
#       'chanceofovercast': '0',
#       'chanceofsunshine': '90',
#       'chanceoffrost': '0',
#       'chanceofhightemp': '15',
#       'chanceoffog': '0',
#       'chanceofsnow': '0',
#       'chanceofthunder': '0',
#       'uvIndex': '6',
#       'shortRad': '146.3',
#       'diffRad': '37.6',
#       'air_quality': {'co': '1922.6',
#        'no2': '65.8',
#        'o3': '45.4',
#        'so2': '79.2',
#        'pm2_5': '103.5',
#        'pm10': '138.3',
#        'us-epa-index': '4',
#        'gb-defra-index': '4'}},
#      {'time': '1200',
#       'tempC': '28',
#       'tempF': '82',
#       'windspeedMiles': '7',
#       'windspeedKmph': '12',
#       'winddirDegree': '336',
#       'winddir16Point': 'NNW',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '33',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1011',
#       'pressureInches': '30',
#       'cloudcover': '0',
#       'HeatIndexC': '27',
#       'HeatIndexF': '80',
#       'DewPointC': '10',
#       'DewPointF': '50',
#       'WindChillC': '28',
#       'WindChillF': '82',
#       'WindGustMiles': '11',
#       'WindGustKmph': '18',
#       'FeelsLikeC': '27',
#       'FeelsLikeF': '80',
#       'chanceofrain': '0',
#       'chanceofremdry': '84',
#       'chanceofwindy': '0',
#       'chanceofovercast': '0',
#       'chanceofsunshine': '86',
#       'chanceoffrost': '0',
#       'chanceofhightemp': '91',
#       'chanceoffog': '0',
#       'chanceofsnow': '0',
#       'chanceofthunder': '0',
#       'uvIndex': '7',
#       'shortRad': '911.9',
#       'diffRad': '127.4',
#       'air_quality': {'co': '1588.8',
#        'no2': '67.2',
#        'o3': '161.7',
#        'so2': '114.4',
#        'pm2_5': '137.2',
#        'pm10': '169.4',
#        'us-epa-index': '4',
#        'gb-defra-index': '4'}},
#      {'time': '1500',
#       'tempC': '28',
#       'tempF': '83',
#       'windspeedMiles': '17',
#       'windspeedKmph': '27',
#       'winddirDegree': '326',
#       'winddir16Point': 'NW',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '45',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1008',
#       'pressureInches': '30',
#       'cloudcover': '0',
#       'HeatIndexC': '28',
#       'HeatIndexF': '83',
#       'DewPointC': '15',
#       'DewPointF': '59',
#       'WindChillC': '28',
#       'WindChillF': '83',
#       'WindGustMiles': '30',
#       'WindGustKmph': '48',
#       'FeelsLikeC': '28',
#       'FeelsLikeF': '83',
#       'chanceofrain': '0',
#       'chanceofremdry': '87',
#       'chanceofwindy': '0',
#       'chanceofovercast': '0',
#       'chanceofsunshine': '93',
#       'chanceoffrost': '0',
#       'chanceofhightemp': '93',
#       'chanceoffog': '0',
#       'chanceofsnow': '0',
#       'chanceofthunder': '0',
#       'uvIndex': '7',
#       'shortRad': '873.6',
#       'diffRad': '126.5',
#       'air_quality': {'co': '580.8',
#        'no2': '15.4',
#        'o3': '186',
#        'so2': '26.5',
#        'pm2_5': '52.3',
#        'pm10': '74',
#        'us-epa-index': '3',
#        'gb-defra-index': '3'}},
#      {'time': '1800',
#       'tempC': '26',
#       'tempF': '80',
#       'windspeedMiles': '17',
#       'windspeedKmph': '28',
#       'winddirDegree': '332',
#       'winddir16Point': 'NNW',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '51',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1009',
#       'pressureInches': '30',
#       'cloudcover': '0',
#       'HeatIndexC': '27',
#       'HeatIndexF': '81',
#       'DewPointC': '16',
#       'DewPointF': '60',
#       'WindChillC': '26',
#       'WindChillF': '80',
#       'WindGustMiles': '30',
#       'WindGustKmph': '47',
#       'FeelsLikeC': '27',
#       'FeelsLikeF': '81',
#       'chanceofrain': '0',
#       'chanceofremdry': '94',
#       'chanceofwindy': '0',
#       'chanceofovercast': '0',
#       'chanceofsunshine': '91',
#       'chanceoffrost': '0',
#       'chanceofhightemp': '89',
#       'chanceoffog': '0',
#       'chanceofsnow': '0',
#       'chanceofthunder': '0',
#       'uvIndex': '7',
#       'shortRad': '99.8',
#       'diffRad': '40.5',
#       'air_quality': {'co': '600.8',
#        'no2': '23.3',
#        'o3': '155.9',
#        'so2': '21.5',
#        'pm2_5': '47',
#        'pm10': '68.1',
#        'us-epa-index': '3',
#        'gb-defra-index': '3'}},
#      {'time': '2100',
#       'tempC': '26',
#       'tempF': '79',
#       'windspeedMiles': '10',
#       'windspeedKmph': '17',
#       'winddirDegree': '351',
#       'winddir16Point': 'N',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear '}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '59',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1010',
#       'pressureInches': '30',
#       'cloudcover': '5',
#       'HeatIndexC': '27',
#       'HeatIndexF': '81',
#       'DewPointC': '17',
#       'DewPointF': '63',
#       'WindChillC': '26',
#       'WindChillF': '79',
#       'WindGustMiles': '19',
#       'WindGustKmph': '30',
#       'FeelsLikeC': '27',
#       'FeelsLikeF': '81',
#       'chanceofrain': '0',
#       'chanceofremdry': '88',
#       'chanceofwindy': '0',
#       'chanceofovercast': '0',
#       'chanceofsunshine': '91',
#       'chanceoffrost': '0',
#       'chanceofhightemp': '88',
#       'chanceoffog': '0',
#       'chanceofsnow': '0',
#       'chanceofthunder': '0',
#       'uvIndex': '1',
#       'shortRad': '25.2',
#       'diffRad': '10.3',
#       'air_quality': {'co': '847.8',
#        'no2': '28.8',
#        'o3': '121.6',
#        'so2': '35.8',
#        'pm2_5': '54.1',
#        'pm10': '82.8',
#        'us-epa-index': '3',
#        'gb-defra-index': '3'}}]},
#    {'date': '2024-02-26',
#     'astronomy': [{'sunrise': '07:01 AM',
#       'sunset': '06:43 PM',
#       'moonrise': '08:16 PM',
#       'moonset': '08:03 AM',
#       'moon_phase': 'Waning Gibbous',
#       'moon_illumination': '98'}],
#     'maxtempC': '27',
#     'maxtempF': '81',
#     'mintempC': '25',
#     'mintempF': '76',
#     'avgtempC': '26',
#     'avgtempF': '79',
#     'totalSnow_cm': '0.0',
#     'sunHour': '11.4',
#     'uvIndex': '9',
#     'air_quality': {'co': '2996.004166666667',
#      'no2': '86.70416666666667',
#      'o3': '60.70833333333332',
#      'so2': '84.96249999999999',
#      'pm2_5': '247.82916666666665',
#      'pm10': '306.0833333333333',
#      'us-epa-index': '5',
#      'gb-defra-index': '5'},
#     'hourly': [{'time': '24',
#       'tempC': '27',
#       'tempF': '81',
#       'windspeedMiles': '13',
#       'windspeedKmph': '22',
#       'winddirDegree': '178',
#       'winddir16Point': 'S',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '56',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1010',
#       'pressureInches': '30',
#       'cloudcover': '7',
#       'HeatIndexC': '27',
#       'HeatIndexF': '80',
#       'DewPointC': '16',
#       'DewPointF': '61',
#       'WindChillC': '26',
#       'WindChillF': '79',
#       'WindGustMiles': '15',
#       'WindGustKmph': '23',
#       'FeelsLikeC': '27',
#       'FeelsLikeF': '80',
#       'chanceofrain': '0',
#       'chanceofremdry': '86',
#       'chanceofwindy': '0',
#       'chanceofovercast': '0',
#       'chanceofsunshine': '94',
#       'chanceoffrost': '0',
#       'chanceofhightemp': '64',
#       'chanceoffog': '0',
#       'chanceofsnow': '0',
#       'chanceofthunder': '0',
#       'uvIndex': '9',
#       'shortRad': '0.0',
#       'diffRad': '0.0',
#       'air_quality': {'co': '2996.004166666667',
#        'no2': '86.70416666666667',
#        'o3': '60.70833333333332',
#        'so2': '84.96249999999999',
#        'pm2_5': '247.82916666666665',
#        'pm10': '306.0833333333333',
#        'us-epa-index': '5',
#        'gb-defra-index': '5'}},
#      {'time': '0',
#       'tempC': '25',
#       'tempF': '78',
#       'windspeedMiles': '3',
#       'windspeedKmph': '5',
#       'winddirDegree': '59',
#       'winddir16Point': 'ENE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear '}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '59',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1010',
#       'pressureInches': '30',
#       'cloudcover': '1',
#       'HeatIndexC': '27',
#       'HeatIndexF': '80',
#       'DewPointC': '17',
#       'DewPointF': '62',
#       'WindChillC': '25',
#       'WindChillF': '78',
#       'WindGustMiles': '5',
#       'WindGustKmph': '9',
#       'FeelsLikeC': '27',
#       'FeelsLikeF': '80',
#       'chanceofrain': '0',
#       'chanceofremdry': '83',
#       'chanceofwindy': '0',
#       'chanceofovercast': '0',
#       'chanceofsunshine': '86',
#       'chanceoffrost': '0',
#       'chanceofhightemp': '87',
#       'chanceoffog': '0',
#       'chanceofsnow': '0',
#       'chanceofthunder': '0',
#       'uvIndex': '1',
#       'shortRad': '0.0',
#       'diffRad': '0.0',
#       'air_quality': {'co': '2136.2',
#        'no2': '75.4',
#        'o3': '44.7',
#        'so2': '67.7',
#        'pm2_5': '122.6',
#        'pm10': '168.3',
#        'us-epa-index': '4',
#        'gb-defra-index': '4'}},
#      {'time': '300',
#       'tempC': '25',
#       'tempF': '77',
#       'windspeedMiles': '7',
#       'windspeedKmph': '12',
#       'winddirDegree': '135',
#       'winddir16Point': 'SE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear '}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '53',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1009',
#       'pressureInches': '30',
#       'cloudcover': '5',
#       'HeatIndexC': '26',
#       'HeatIndexF': '78',
#       'DewPointC': '15',
#       'DewPointF': '58',
#       'WindChillC': '25',
#       'WindChillF': '77',
#       'WindGustMiles': '13',
#       'WindGustKmph': '21',
#       'FeelsLikeC': '26',
#       'FeelsLikeF': '78',
#       'chanceofrain': '0',
#       'chanceofremdry': '82',
#       'chanceofwindy': '0',
#       'chanceofovercast': '0',
#       'chanceofsunshine': '92',
#       'chanceoffrost': '0',
#       'chanceofhightemp': '15',
#       'chanceoffog': '0',
#       'chanceofsnow': '0',
#       'chanceofthunder': '0',
#       'uvIndex': '1',
#       'shortRad': '0.0',
#       'diffRad': '0.0',
#       'air_quality': {'co': '2964',
#        'no2': '104.2',
#        'o3': '2.4',
#        'so2': '84.9',
#        'pm2_5': '200',
#        'pm10': '252.7',
#        'us-epa-index': '5',
#        'gb-defra-index': '5'}},
#      {'time': '600',
#       'tempC': '25',
#       'tempF': '77',
#       'windspeedMiles': '4',
#       'windspeedKmph': '7',
#       'winddirDegree': '89',
#       'winddir16Point': 'E',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear '}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '44',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1010',
#       'pressureInches': '30',
#       'cloudcover': '21',
#       'HeatIndexC': '25',
#       'HeatIndexF': '78',
#       'DewPointC': '12',
#       'DewPointF': '53',
#       'WindChillC': '25',
#       'WindChillF': '77',
#       'WindGustMiles': '7',
#       'WindGustKmph': '12',
#       'FeelsLikeC': '25',
#       'FeelsLikeF': '78',
#       'chanceofrain': '0',
#       'chanceofremdry': '80',
#       'chanceofwindy': '0',
#       'chanceofovercast': '0',
#       'chanceofsunshine': '91',
#       'chanceoffrost': '0',
#       'chanceofhightemp': '15',
#       'chanceoffog': '0',
#       'chanceofsnow': '0',
#       'chanceofthunder': '0',
#       'uvIndex': '1',
#       'shortRad': '0.0',
#       'diffRad': '0.0',
#       'air_quality': {'co': '1842.5',
#        'no2': '69.9',
#        'o3': '1.1',
#        'so2': '51.5',
#        'pm2_5': '147.1',
#        'pm10': '180.3',
#        'us-epa-index': '4',
#        'gb-defra-index': '4'}},
#      {'time': '900',
#       'tempC': '26',
#       'tempF': '79',
#       'windspeedMiles': '5',
#       'windspeedKmph': '8',
#       'winddirDegree': '126',
#       'winddir16Point': 'SE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '40',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1012',
#       'pressureInches': '30',
#       'cloudcover': '10',
#       'HeatIndexC': '26',
#       'HeatIndexF': '79',
#       'DewPointC': '11',
#       'DewPointF': '53',
#       'WindChillC': '26',
#       'WindChillF': '79',
#       'WindGustMiles': '8',
#       'WindGustKmph': '12',
#       'FeelsLikeC': '26',
#       'FeelsLikeF': '79',
#       'chanceofrain': '0',
#       'chanceofremdry': '80',
#       'chanceofwindy': '0',
#       'chanceofovercast': '0',
#       'chanceofsunshine': '92',
#       'chanceoffrost': '0',
#       'chanceofhightemp': '84',
#       'chanceoffog': '0',
#       'chanceofsnow': '0',
#       'chanceofthunder': '0',
#       'uvIndex': '7',
#       'shortRad': '138.4',
#       'diffRad': '40.5',
#       'air_quality': {'co': '3898.6',
#        'no2': '105.6',
#        'o3': '20.4',
#        'so2': '109.7',
#        'pm2_5': '291.9',
#        'pm10': '354.8',
#        'us-epa-index': '6',
#        'gb-defra-index': '6'}},
#      {'time': '1200',
#       'tempC': '27',
#       'tempF': '81',
#       'windspeedMiles': '9',
#       'windspeedKmph': '15',
#       'winddirDegree': '235',
#       'winddir16Point': 'SW',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '45',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1011',
#       'pressureInches': '30',
#       'cloudcover': '7',
#       'HeatIndexC': '27',
#       'HeatIndexF': '81',
#       'DewPointC': '14',
#       'DewPointF': '57',
#       'WindChillC': '27',
#       'WindChillF': '81',
#       'WindGustMiles': '15',
#       'WindGustKmph': '24',
#       'FeelsLikeC': '27',
#       'FeelsLikeF': '81',
#       'chanceofrain': '0',
#       'chanceofremdry': '83',
#       'chanceofwindy': '0',
#       'chanceofovercast': '0',
#       'chanceofsunshine': '90',
#       'chanceoffrost': '0',
#       'chanceofhightemp': '87',
#       'chanceoffog': '0',
#       'chanceofsnow': '0',
#       'chanceofthunder': '0',
#       'uvIndex': '7',
#       'shortRad': '845.5',
#       'diffRad': '228.9',
#       'air_quality': {'co': '1895.9',
#        'no2': '56.2',
#        'o3': '217.4',
#        'so2': '65.8',
#        'pm2_5': '247.1',
#        'pm10': '290.8',
#        'us-epa-index': '5',
#        'gb-defra-index': '5'}},
#      {'time': '1500',
#       'tempC': '27',
#       'tempF': '81',
#       'windspeedMiles': '13',
#       'windspeedKmph': '22',
#       'winddirDegree': '240',
#       'winddir16Point': 'WSW',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '62',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1009',
#       'pressureInches': '30',
#       'cloudcover': '7',
#       'HeatIndexC': '29',
#       'HeatIndexF': '83',
#       'DewPointC': '19',
#       'DewPointF': '67',
#       'WindChillC': '27',
#       'WindChillF': '81',
#       'WindGustMiles': '19',
#       'WindGustKmph': '31',
#       'FeelsLikeC': '29',
#       'FeelsLikeF': '83',
#       'chanceofrain': '0',
#       'chanceofremdry': '83',
#       'chanceofwindy': '0',
#       'chanceofovercast': '0',
#       'chanceofsunshine': '87',
#       'chanceoffrost': '0',
#       'chanceofhightemp': '82',
#       'chanceoffog': '0',
#       'chanceofsnow': '0',
#       'chanceofthunder': '0',
#       'uvIndex': '7',
#       'shortRad': '814.8',
#       'diffRad': '213.1',
#       'air_quality': {'co': '494',
#        'no2': '9.4',
#        'o3': '154.5',
#        'so2': '15.3',
#        'pm2_5': '66.9',
#        'pm10': '97',
#        'us-epa-index': '4',
#        'gb-defra-index': '4'}},
#      {'time': '1800',
#       'tempC': '26',
#       'tempF': '79',
#       'windspeedMiles': '8',
#       'windspeedKmph': '13',
#       'winddirDegree': '252',
#       'winddir16Point': 'WSW',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '71',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1010',
#       'pressureInches': '30',
#       'cloudcover': '6',
#       'HeatIndexC': '28',
#       'HeatIndexF': '83',
#       'DewPointC': '21',
#       'DewPointF': '69',
#       'WindChillC': '26',
#       'WindChillF': '79',
#       'WindGustMiles': '12',
#       'WindGustKmph': '19',
#       'FeelsLikeC': '28',
#       'FeelsLikeF': '83',
#       'chanceofrain': '0',
#       'chanceofremdry': '84',
#       'chanceofwindy': '0',
#       'chanceofovercast': '0',
#       'chanceofsunshine': '91',
#       'chanceoffrost': '0',
#       'chanceofhightemp': '81',
#       'chanceoffog': '0',
#       'chanceofsnow': '0',
#       'chanceofthunder': '0',
#       'uvIndex': '7',
#       'shortRad': '92.9',
#       'diffRad': '43.2',
#       'air_quality': {'co': '794.4',
#        'no2': '32.9',
#        'o3': '95.8',
#        'so2': '19.8',
#        'pm2_5': '64.1',
#        'pm10': '94.4',
#        'us-epa-index': '3',
#        'gb-defra-index': '3'}},
#      {'time': '2100',
#       'tempC': '26',
#       'tempF': '78',
#       'windspeedMiles': '3',
#       'windspeedKmph': '5',
#       'winddirDegree': '239',
#       'winddir16Point': 'WSW',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear '}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '73',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1013',
#       'pressureInches': '30',
#       'cloudcover': '3',
#       'HeatIndexC': '28',
#       'HeatIndexF': '82',
#       'DewPointC': '20',
#       'DewPointF': '69',
#       'WindChillC': '26',
#       'WindChillF': '78',
#       'WindGustMiles': '5',
#       'WindGustKmph': '8',
#       'FeelsLikeC': '28',
#       'FeelsLikeF': '82',
#       'chanceofrain': '0',
#       'chanceofremdry': '89',
#       'chanceofwindy': '0',
#       'chanceofovercast': '0',
#       'chanceofsunshine': '90',
#       'chanceoffrost': '0',
#       'chanceofhightemp': '80',
#       'chanceoffog': '0',
#       'chanceofsnow': '0',
#       'chanceofthunder': '0',
#       'uvIndex': '1',
#       'shortRad': '23.5',
#       'diffRad': '10.9',
#       'air_quality': {'co': '3070.8',
#        'no2': '112.4',
#        'o3': '26.8',
#        'so2': '84.9',
#        'pm2_5': '228.7',
#        'pm10': '304.5',
#        'us-epa-index': '5',
#        'gb-defra-index': '5'}}]}],
#   'ClimateAverages': [{'month': [{'index': '1',
#       'name': 'January',
#       'avgMinTemp': '21.8',
#       'avgMinTemp_F': '71.2',
#       'absMaxTemp': '31.5548',
#       'absMaxTemp_F': '88.8',
#       'avgDailyRainfall': '0.04'},
#      {'index': '2',
#       'name': 'February',
#       'avgMinTemp': '22.8',
#       'avgMinTemp_F': '73.0',
#       'absMaxTemp': '32.5518',
#       'absMaxTemp_F': '90.6',
#       'avgDailyRainfall': '0.02'},
#      {'index': '3',
#       'name': 'March',
#       'avgMinTemp': '24.9',
#       'avgMinTemp_F': '76.8',
#       'absMaxTemp': '33.9317',
#       'absMaxTemp_F': '93.1',
#       'avgDailyRainfall': '0.04'},
#      {'index': '4',
#       'name': 'April',
#       'avgMinTemp': '26.6',
#       'avgMinTemp_F': '79.9',
#       'absMaxTemp': '34.3711',
#       'absMaxTemp_F': '93.9',
#       'avgDailyRainfall': '0.03'},
#      {'index': '5',
#       'name': 'May',
#       'avgMinTemp': '27.9',
#       'avgMinTemp_F': '82.2',
#       'absMaxTemp': '34.3172',
#       'absMaxTemp_F': '93.8',
#       'avgDailyRainfall': '0.37'},
#      {'index': '6',
#       'name': 'June',
#       'avgMinTemp': '27.6',
#       'avgMinTemp_F': '81.7',
#       'absMaxTemp': '32.1311',
#       'absMaxTemp_F': '89.8',
#       'avgDailyRainfall': '13.97'},
#      {'index': '7',
#       'name': 'July',
#       'avgMinTemp': '26.5',
#       'avgMinTemp_F': '79.7',
#       'absMaxTemp': '29.3022',
#       'absMaxTemp_F': '84.7',
#       'avgDailyRainfall': '25.89'},
#      {'index': '8',
#       'name': 'August',
#       'avgMinTemp': '26.1',
#       'avgMinTemp_F': '78.9',
#       'absMaxTemp': '28.9893',
#       'absMaxTemp_F': '84.2',
#       'avgDailyRainfall': '14.12'},
#      {'index': '9',
#       'name': 'September',
#       'avgMinTemp': '26.0',
#       'avgMinTemp_F': '78.7',
#       'absMaxTemp': '30.5139',
#       'absMaxTemp_F': '86.9',
#       'avgDailyRainfall': '11.49'},
#      {'index': '10',
#       'name': 'October',
#       'avgMinTemp': '26.2',
#       'avgMinTemp_F': '79.1',
#       'absMaxTemp': '34.2952',
#       'absMaxTemp_F': '93.7',
#       'avgDailyRainfall': '2.71'},
#      {'index': '11',
#       'name': 'November',
#       'avgMinTemp': '25.0',
#       'avgMinTemp_F': '77.0',
#       'absMaxTemp': '34.6367',
#       'absMaxTemp_F': '94.3',
#       'avgDailyRainfall': '0.84'},
#      {'index': '12',
#       'name': 'December',
#       'avgMinTemp': '23.1',
#       'avgMinTemp_F': '73.6',
#       'absMaxTemp': '32.6591',
#       'absMaxTemp_F': '90.8',
#       'avgDailyRainfall': '0.24'}]}],
#   'alerts': {'alert': []}}}

# %%
def generate_weather_summary(api_output):
    try:
        # Extracting current weather conditions
        current_conditions = api_output['data']['current_condition'][0]
        current_summary = (
            f"Current weather observation at {current_conditions['observation_time']}:\n"
            f"Temperature: {current_conditions['temp_C']}°C ({current_conditions['temp_F']}°F)\n"
            f"Condition: {current_conditions['weatherDesc'][0]['value']}\n"
            f"Wind: {current_conditions['windspeedKmph']} km/h from {current_conditions['winddir16Point']}\n"
            f"Humidity: {current_conditions['humidity']}%\n"
            f"Visibility: {current_conditions['visibility']} km\n"
            f"Pressure: {current_conditions['pressure']} mb\n"
            f"UV Index: {current_conditions.get('uvIndex', 'N/A')}\n"
        )

        # Extracting weather forecast for the next 24 hours
        today_forecast = api_output['data']['weather'][0]
        hourly_forecasts = today_forecast['hourly']
        next_24h_summary = "Weather forecast for the next 24 hours:\n"
        for forecast in hourly_forecasts:
            next_24h_summary += (
                f"Time: {forecast['time']} - "
                f"Temperature: {forecast['tempC']}°C ({forecast['tempF']}°F), "
                f"Condition: {forecast['weatherDesc'][0]['value']}, "
                f"Wind: {forecast['windspeedKmph']} km/h, "
                f"Chance of rain: {forecast['chanceofrain']}%\n"
            )

        # Extracting weather forecast for the next 7 days
        weekly_forecast = api_output['data']['weather']
        next_7d_summary = "Weather forecast for the next 7 days:\n"
        for day in weekly_forecast:
            next_7d_summary += (
                f"Date: {day['date']} - "
                f"Max Temp: {day['maxtempC']}°C ({day['maxtempF']}°F), "
                f"Min Temp: {day['mintempC']}°C ({day['mintempF']}°F), "
                f"UV Index: {day['uvIndex']}\n"
            )

        # Combining all summaries
        full_summary = current_summary + "\n" + next_24h_summary + "\n" + next_7d_summary

        return full_summary
    except KeyError as e:
        return f"KeyError: The key {str(e)} is missing in the API output."

# Assuming 'weather_api_output' is the variable containing the API output
print(generate_weather_summary(data))
# Out:
# Current weather observation at 07:17 PM:
# Temperature: 25°C (77°F)
# Condition: Smoke
# Wind: 9 km/h from N
# Humidity: 28%
# Visibility: 3 km
# Pressure: 1012 mb
# UV Index: 1
#
# Weather forecast for the next 24 hours:
# Time: 24 - Temperature: 28°C (83°F), Condition: Sunny, Wind: 30 km/h, Chance of rain: 0%
# Time: 0 - Temperature: 25°C (76°F), Condition: Clear , Wind: 14 km/h, Chance of rain: 0%
# Time: 300 - Temperature: 24°C (75°F), Condition: Clear , Wind: 18 km/h, Chance of rain: 0%
# Time: 600 - Temperature: 23°C (74°F), Condition: Clear , Wind: 19 km/h, Chance of rain: 0%
# Time: 900 - Temperature: 24°C (76°F), Condition: Sunny, Wind: 15 km/h, Chance of rain: 0%
# Time: 1200 - Temperature: 28°C (82°F), Condition: Sunny, Wind: 12 km/h, Chance of rain: 0%
# Time: 1500 - Temperature: 28°C (83°F), Condition: Sunny, Wind: 27 km/h, Chance of rain: 0%
# Time: 1800 - Temperature: 26°C (80°F), Condition: Sunny, Wind: 28 km/h, Chance of rain: 0%
# Time: 2100 - Temperature: 26°C (79°F), Condition: Clear , Wind: 17 km/h, Chance of rain: 0%
#
# Weather forecast for the next 7 days:
# Date: 2024-02-25 - Max Temp: 28°C (83°F), Min Temp: 23°C (73°F), UV Index: 10
# Date: 2024-02-26 - Max Temp: 27°C (81°F), Min Temp: 25°C (76°F), UV Index: 9

# %%
# !pip install langchain_google_genai
# Out:
# Collecting langchain_google_genai
#   Downloading langchain_google_genai-0.0.9-py3-none-any.whl (17 kB)
# Collecting google-generativeai<0.4.0,>=0.3.1 (from langchain_google_genai)
#   Downloading google_generativeai-0.3.2-py3-none-any.whl (146 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.9/146.9 kB 2.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: langchain-core<0.2,>=0.1 in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from langchain_google_genai) (0.1.0)
# Collecting google-ai-generativelanguage==0.4.0 (from google-generativeai<0.4.0,>=0.3.1->langchain_google_genai)
#   Downloading google_ai_generativelanguage-0.4.0-py3-none-any.whl (598 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 598.7/598.7 kB 7.1 MB/s eta 0:00:0000:0100:01
# Collecting google-auth (from google-generativeai<0.4.0,>=0.3.1->langchain_google_genai)
#   Downloading google_auth-2.28.1-py2.py3-none-any.whl (186 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.9/186.9 kB 6.2 MB/s eta 0:00:00
# Collecting google-api-core (from google-generativeai<0.4.0,>=0.3.1->langchain_google_genai)
#   Downloading google_api_core-2.17.1-py3-none-any.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.0/137.0 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from google-generativeai<0.4.0,>=0.3.1->langchain_google_genai) (4.5.0)
# Requirement already satisfied: protobuf in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from google-generativeai<0.4.0,>=0.3.1->langchain_google_genai) (4.23.0)
# Requirement already satisfied: tqdm in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from google-generativeai<0.4.0,>=0.3.1->langchain_google_genai) (4.66.1)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-ai-generativelanguage==0.4.0->google-generativeai<0.4.0,>=0.3.1->langchain_google_genai)
#   Downloading proto_plus-1.23.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from langchain-core<0.2,>=0.1->langchain_google_genai) (6.0)
# Requirement already satisfied: anyio<5,>=3 in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from langchain-core<0.2,>=0.1->langchain_google_genai) (3.6.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from langchain-core<0.2,>=0.1->langchain_google_genai) (1.33)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.63 in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from langchain-core<0.2,>=0.1->langchain_google_genai) (0.0.70)
# Requirement already satisfied: packaging<24.0,>=23.2 in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from langchain-core<0.2,>=0.1->langchain_google_genai) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from langchain-core<0.2,>=0.1->langchain_google_genai) (1.10.7)
# Requirement already satisfied: requests<3,>=2 in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from langchain-core<0.2,>=0.1->langchain_google_genai) (2.28.2)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from langchain-core<0.2,>=0.1->langchain_google_genai) (8.2.2)
# Requirement already satisfied: idna>=2.8 in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1->langchain_google_genai) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1->langchain_google_genai) (1.3.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2,>=0.1->langchain_google_genai) (2.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from requests<3,>=2->langchain-core<0.2,>=0.1->langchain_google_genai) (3.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from requests<3,>=2->langchain-core<0.2,>=0.1->langchain_google_genai) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from requests<3,>=2->langchain-core<0.2,>=0.1->langchain_google_genai) (2023.5.7)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core->google-generativeai<0.4.0,>=0.3.1->langchain_google_genai)
#   Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl (228 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.7/228.7 kB 6.2 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0 (from google-auth->google-generativeai<0.4.0,>=0.3.1->langchain_google_genai)
#   Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from google-auth->google-generativeai<0.4.0,>=0.3.1->langchain_google_genai) (0.3.0)
# Collecting rsa<5,>=3.1.4 (from google-auth->google-generativeai<0.4.0,>=0.3.1->langchain_google_genai)
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from google-api-core->google-generativeai<0.4.0,>=0.3.1->langchain_google_genai) (1.53.0)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core->google-generativeai<0.4.0,>=0.3.1->langchain_google_genai)
#   Downloading grpcio_status-1.62.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth->google-generativeai<0.4.0,>=0.3.1->langchain_google_genai) (0.5.0)
# Collecting grpcio<2.0dev,>=1.33.2 (from google-api-core->google-generativeai<0.4.0,>=0.3.1->langchain_google_genai)
#   Downloading grpcio-1.62.0-cp310-cp310-macosx_12_0_universal2.whl (10.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 8.0 MB/s eta 0:00:0000:010:01m
# Installing collected packages: rsa, proto-plus, grpcio, googleapis-common-protos, cachetools, grpcio-status, google-auth, google-api-core, google-ai-generativelanguage, google-generativeai, langchain_google_genai
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.53.0
#     Uninstalling grpcio-1.53.0:
#       Successfully uninstalled grpcio-1.53.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pymilvus 2.2.8 requires grpcio<=1.53.0,>=1.49.1, but you have grpcio 1.62.0 which is incompatible.
# Successfully installed cachetools-5.3.2 google-ai-generativelanguage-0.4.0 google-api-core-2.17.1 google-auth-2.28.1 google-generativeai-0.3.2 googleapis-common-protos-1.62.0 grpcio-1.62.0 grpcio-status-1.62.0 langchain_google_genai-0.0.9 proto-plus-1.23.0 rsa-4.9
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
from langchain_core.messages import HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI
import os

llm = ChatGoogleGenerativeAI(model="gemini-pro-vision")
# example
message = HumanMessage(
    content=[
        {
            "type": "text",
            "text": "What's in this image?",
        },  # You can optionally provide text parts
        {
            "type": "image_url",
            "image_url": f'data:image/png;base64,${base64_encoded_image}'
        },
    ]
)
llm.invoke([message])
# Out:
# AIMessage(content=' This is a field of green onions.')

# %%
# !pip install googletrans
# Out:
# Collecting googletrans
#   Downloading googletrans-3.0.0.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans)
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 982.2 kB/s eta 0:00:00 0:00:01
# Requirement already satisfied: certifi in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from httpx==0.13.3->googletrans) (2023.5.7)
# Collecting hstspreload (from httpx==0.13.3->googletrans)
#   Downloading hstspreload-2024.2.1-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 9.7 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: sniffio in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from httpx==0.13.3->googletrans) (1.3.0)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 4.9 MB/s eta 0:00:00
# Collecting idna==2.* (from httpx==0.13.3->googletrans)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: rfc3986<2,>=1.3 in /Users/mufaddal/Library/Caches/pypoetry/virtualenvs/chatgpt-retrieval-plugin-PoQvrHGN-py3.10/lib/python3.10/site-packages (from httpx==0.13.3->googletrans) (1.5.0)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans)
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 1.3 MB/s eta 0:00:00
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans)
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 1.9 MB/s eta 0:00:00
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans)
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 2.3 MB/s eta 0:00:00
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.0.0-py3-none-any.whl size=15721 sha256=a26d37ddb3fc7f06e572cfd5229ee0b3aff8dcb6bdb7bc08408c5688e0620909
#   Stored in directory: /Users/mufaddal/Library/Caches/pip/wheels/b3/81/ea/8b030407f8ebfc2f857814e086bb22ca2d4fea1a7be63652ab
# Successfully built googletrans
# Installing collected packages: hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: hyperframe
#     Found existing installation: hyperframe 6.0.1
#     Uninstalling hyperframe-6.0.1:
#       Successfully uninstalled hyperframe-6.0.1
#   Attempting uninstall: hpack
#     Found existing installation: hpack 4.0.0
#     Uninstalling hpack-4.0.0:
#       Successfully uninstalled hpack-4.0.0
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: h2
#     Found existing installation: h2 4.1.0
#     Uninstalling h2-4.1.0:
#       Successfully uninstalled h2-4.1.0
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 0.16.3
#     Uninstalling httpcore-0.16.3:
#       Successfully uninstalled httpcore-0.16.3
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.23.3
#     Uninstalling httpx-0.23.3:
#       Successfully uninstalled httpx-0.23.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chatgpt-retrieval-plugin 0.1.0 requires chardet<6.0.0,>=5.2.0, but you have chardet 3.0.4 which is incompatible.
# qdrant-client 1.1.6 requires httpx[http2]>=0.14.0, but you have httpx 0.13.3 which is incompatible.
# Successfully installed chardet-3.0.4 googletrans-3.0.0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2024.2.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
